# %% [markdown]
# Data Description

# %% [markdown]
# The dataset contains 9358 instances of hourly averaged responses from an array of 5 metal oxide chemical sensors embedded in an Air Quality Chemical Multisensor Device.
#
# The device was located on the field in a significantly polluted area, at road level, within an Italian city. Data were recorded from March 2004 to April 2005 (one year) representing the longest freely available recordings of on field-deployed air quality chemical sensor devices responses. A co-located reference certified analyzer provided Ground Truth (GT) hourly averaged concentrations for Carbon Monoxide ( CO ), Non-Methane Hydrocarbons ( NMHC ), Benzene ( C6H6 ), total Nitrogen Oxides ( NOx ) & Nitrogen Dioxide ( NO2 ) and Ozone ( O3 ). These chemical compounds are commonly occurring air pollutants.
#
# Index	Columns	                   Description
# 0	Date	           Date (DD/MM/YYYY)
# 1	Time	           Time (HH.MM.SS)
# 2	CO(GT)	           True hourly averaged concentration  CO  in  mgm3  (reference analyzer)
# 3	PT08.S1(CO)	       PT08.S1 (tin oxide) hourly averaged sensor response (nominally  CO  targeted)
# 4	NMHC(GT)	       True hourly averaged overall Non-Methane Hydrocarbons concentration in  μgm3
# 5	C6H6(GT)	       True hourly averaged Benzene concentration in  μgm3
# 6	PT08.S2(NMHC)	   PT08.S2 (titania) hourly averaged sensor response (nominally  NMHC  targeted)
# 7	NOx(GT)	           True hourly averaged  NOx  concentration in Parts per billion (ppb)
# 8	PT08.S3(NOx)	   PT08.S3 (tungsten oxide) hourly averaged sensor response (nominally  NOx  targeted)
# 9	NO2(GT)	           True hourly averaged  NO2  concentration in  μgm3
# 10	PT08.S4(NO2)	   PT08.S4 (tungsten oxide) hourly averaged sensor response (nominally  NO2  targeted)
# 11	PT08.S5(O3)	       PT08.S5 (indium oxide) hourly averaged sensor response (nominally  O3  targeted)
# 12	T	               Temperature in Â°C
# 13	RH	               Relative Humidity (%)
# 14	AH	               AH Absolute Humidity
#
# The above dataset contains missing (or null) values and -200 as garbage value.

# %% [markdown]
# About Air Pollutants
#
#
# Carbon Monoxide ( CO ):
# It is a poisonous gas. It reacts with haemoglobin because of which it is unable to supply oxygen to the human body. At very high concentrations of carbon monoxide, up to 40% of the haemoglobin can bind with carbon monoxide which is enough to certainly kill humans. Carbon monoxide is also known as the silent killer because it has no colour, taste or smell.
#
# Benzene ( C6H6 ):
# It is a colorless or light yellow liquid at room temperature. It has a sweet odour and is highly flammable. It evaporates into the air very quickly, but its vapour is heavier than air and may sink into low-lying areas. Outdoor air contains low levels of benzene from tobacco smoke, gas stations, motor vehicle exhaust, and industrial emissions. Indoor air generally contains levels of benzene higher than those in outdoor air. The benzene in indoor air comes from products that contain benzene such as glues, paints, furniture wax, and detergents. The air around hazardous waste sites or gas stations can contain higher levels of benzene than in other areas. Tobacco smoke is also a major source of benzene.
# People who breathe in high levels of benzene may develop drowsiness, dizziness, rapid or irregular heartbeat, headaches, tremors, confusion, unconsciousness and death (at very high levels)
#
# Nitrogen Oxides ( NOx ) & Nitrogen Dioxide ( NO2 ):
# Nitrogen dioxide and nitric oxide together are referred to as oxides of nitrogen ( NOx ).
# Nitrogen dioxide is an irritant gas. When nitrogen is released during fuel combustion, it combines with oxygen atoms to create nitric oxide ( NO ). This further combines with oxygen to create nitrogen dioxide ( NO2 ). Nitric oxide is not considered to be hazardous to health at typical ambient concentrations, but nitrogen dioxide can be.
#
# NOx  gases react to form smog and acid rain as well as being central to the formation of fine particles (PM) and ground level ozone, both of which are associated with adverse health effects.
#
# Ozone ( O3 ):
# Ozone is a colourless and odourless gas. Ground-level ozone forms when pollutants from cars and trucks, power plants, factories, and other sources come in contact with each other in heat and sunlight. Ground-level ozone is one of the biggest parts of smog, and it is usually worse in the summer months.
#
# Many scientific studies have linked ground-level ozone contact to such varied problems as asthma, bronchitis, and emphysema
# pneumonia or bronchitis lung and throat irritation Non-Methane Hydrocarbons ( NMHC )
#
# All the hydrocarbons except for methane ( CH4 ) are collectively called Non-Methane Hydrocarbons. The elevated ambient concentration of NMHCs in an urban environment has a significant impact on climate change and human health.
#
# Hydrocarbons (or organic compounds) are naturally occurring substances that can be found in all living things. The solvents being emitted from manufacturing processes are considered Volatile Organic Compounds (VOC). The hydrocarbons are considered volatile since they produce a vapour at room temperature and normal atmospheric pressure. VOCs are contributors to the formation of ozone and smog.
#
# The mechanism for ozone production is:
# VOC+NOx+sunlight (UV)⟶O3
#
# Hydrocarbons are the main component of crude oil, natural gases, and most pesticides. All of these substances contribute to the greenhouse effect, and the depletion of the ozone layer. They also reduce the photosynthetic ability of plants, increase cancer rates in humans and animals, and increase the risk of respiratory illness.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\Courses\Python, ML Course_Vidushi\AirQualityUCI-(project Analysis from 38-44).csv", sep=';')
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  ,,,,,          2556 non-null   object
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (9471, 17)

# %%
df.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# ,,,,,            6915
# dtype: int64

# %%
df.drop(['Unnamed: 15',',,,,,'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
#Drop the rows containing at least one null value in the 'df' DataFrame using the 'dropna()' function.
df=df.dropna()
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.shape
# Out:
# (9357, 15)

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# Parsing datetime Values - pd.to_datetime() Function^
#
# Convert the values stored in the Date and Time columns to datetime values so as to sort the DataFrame in the chronological order.
#
# Concatenate the values stored in the Date and Time columns and store them into a new Pandas series.
#
# Convert these concatenated values to the datetime values using the pd.to_datetime() function from the Pandas module.

# %%
#Concatenate the values stored in the 'Date' and 'Time' columns and store them into a new Pandas series.(yyyy-mm-dd)
d1=[i.split('/')[2]+'-'+i.split('/')[1]+'-'+i.split('/')[0] for i in df['Date']]
t1=[str(i).replace('.',':') for i in df['Time']]

#ensure that the indices of the new series are the same as the indices of the df DataFrame.

dt_series=pd.Series(data=d1, index=df.index)+'  ,  '+ pd.Series(data=t1, index=df.index)
dt_series= pd.to_datetime(dt_series)
dt_series
# Out:
# 0      2004-03-10 18:00:00
# 1      2004-03-10 19:00:00
# 2      2004-03-10 20:00:00
# 3      2004-03-10 21:00:00
# 4      2004-03-10 22:00:00
#                ...
# 9352   2005-04-04 10:00:00
# 9353   2005-04-04 11:00:00
# 9354   2005-04-04 12:00:00
# 9355   2005-04-04 13:00:00
# 9356   2005-04-04 14:00:00
# Length: 9357, dtype: datetime64[ns]

# %%
#df=df.drop(columns=['Date','Time'])
#df=df.insert(0, dt_series,"Datetime")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=df.drop(['Date', 'Time'], axis=1)
df.insert(0,"Datetime", dt_series,True)

# %%
print(df.iloc[:,3])
# Out:
# 0       150.0
# 1       112.0
# 2        88.0
# 3        80.0
# 4        51.0
#         ...
# 9352   -200.0
# 9353   -200.0
# 9354   -200.0
# 9355   -200.0
# 9356   -200.0
# Name: NMHC(GT), Length: 9357, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                 Datetime CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0    2004-03-10 18:00:00    2,6       1360.0     150.0     11,9
# 1    2004-03-10 19:00:00      2       1292.0     112.0      9,4
# 2    2004-03-10 20:00:00    2,2       1402.0      88.0      9,0
# 3    2004-03-10 21:00:00    2,2       1376.0      80.0      9,2
# 4    2004-03-10 22:00:00    1,6       1272.0      51.0      6,5
# ...                  ...    ...          ...       ...      ...
# 9352 2005-04-04 10:00:00    3,1       1314.0    -200.0     13,5
# 9353 2005-04-04 11:00:00    2,4       1163.0    -200.0     11,4
# 9354 2005-04-04 12:00:00    2,4       1142.0    -200.0     12,4
# 9355 2005-04-04 13:00:00    2,1       1003.0    -200.0      9,5
# 9356 2005-04-04 14:00:00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# Extract Year, Month, Day & Weekday Values^ (syntax:series_name.dt.year)
#
# We can add a column to a DataFrame by following the syntax given below.
#
# Syntax: df_name['column_name'] = pandas_series

# %%
dt_year= dt_series.dt.year
dt_month= dt_series.dt.month
dt_date=dt_series.dt.date
dt_dayname=dt_series.dt.day_name()

# %%
df['Year']=dt_year
df['Month']=dt_month
df['Date']=dt_date
df['Dayname']=dt_dayname

# %%
df.head()
# Out:
#              Datetime CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10 18:00:00    2,6       1360.0     150.0     11,9         1046.0
# 1 2004-03-10 19:00:00      2       1292.0     112.0      9,4          955.0
# 2 2004-03-10 20:00:00    2,2       1402.0      88.0      9,0          939.0
# 3 2004-03-10 21:00:00    2,2       1376.0      80.0      9,2          948.0
# 4 2004-03-10 22:00:00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Year  Month        Date    Dayname
# ...

# %%
df=df.sort_values(by='Datetime')
df.head()
# Out:
#              Datetime CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10 18:00:00    2,6       1360.0     150.0     11,9         1046.0
# 1 2004-03-10 19:00:00      2       1292.0     112.0      9,4          955.0
# 2 2004-03-10 20:00:00    2,2       1402.0      88.0      9,0          939.0
# 3 2004-03-10 21:00:00    2,2       1376.0      80.0      9,2          948.0
# 4 2004-03-10 22:00:00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Year  Month        Date    Dayname
# ...

# %%
def commas(series):
    n1=([float(i.replace(',','.'))for i in series])
    new=pd.Series(data=n1,index=df.index)
    return new

# %%
list=['CO(GT)', 'C6H6(GT)', 'T', 'RH', 'AH']
for i in list:
    df[i]=commas(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9357 entries, 0 to 9356
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Datetime       9357 non-null   datetime64[ns]
#  1   CO(GT)         9357 non-null   float64
#  2   PT08.S1(CO)    9357 non-null   float64
#  3   NMHC(GT)       9357 non-null   float64
#  4   C6H6(GT)       9357 non-null   float64
#  5   PT08.S2(NMHC)  9357 non-null   float64
#  6   NOx(GT)        9357 non-null   float64
#  7   PT08.S3(NOx)   9357 non-null   float64
#  8   NO2(GT)        9357 non-null   float64
#  9   PT08.S4(NO2)   9357 non-null   float64
#  10  PT08.S5(O3)    9357 non-null   float64
#  11  T              9357 non-null   float64
#  12  RH             9357 non-null   float64
#  13  AH             9357 non-null   float64
#  14  Year           9357 non-null   int64
#  15  Month          9357 non-null   int64
#  16  Date           9357 non-null   object
# ...

# %%
#Get the descriptive statistics for all the numeric data-type columns.
df.iloc[:,1:-4].describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
#How many rows contain -200 in each column except for the 'DateTime', 'Year', 'Month' and 'Day' columns?
count_list=[[col,df[df[col]==-200].shape[0]] for col in df.columns[1:-4]]
count_list
# Out:
# [['CO(GT)', 1683],
#  ['PT08.S1(CO)', 366],
#  ['NMHC(GT)', 8443],
#  ['C6H6(GT)', 366],
#  ['PT08.S2(NMHC)', 366],
#  ['NOx(GT)', 1639],
#  ['PT08.S3(NOx)', 366],
#  ['NO2(GT)', 1642],
#  ['PT08.S4(NO2)', 366],
#  ['PT08.S5(O3)', 366],
#  ['T', 366],
#  ['RH', 366],
#  ['AH', 366]]

# %%
#the percentage of rows contain -200 in each column except for the 'DateTime', 'Year', 'Month' and 'Day' columns.
percent_list=[[count_list[i][0],round((count_list[i][1])*100/df.shape[0],3)]for i in range(len(count_list))]
percent_list
# Out:
# [['CO(GT)', 17.987],
#  ['PT08.S1(CO)', 3.912],
#  ['NMHC(GT)', 90.232],
#  ['C6H6(GT)', 3.912],
#  ['PT08.S2(NMHC)', 3.912],
#  ['NOx(GT)', 17.516],
#  ['PT08.S3(NOx)', 3.912],
#  ['NO2(GT)', 17.548],
#  ['PT08.S4(NO2)', 3.912],
#  ['PT08.S5(O3)', 3.912],
#  ['T', 3.912],
#  ['RH', 3.912],
#  ['AH', 3.912]]

# %%
#Remove all the columns from the 'df' DataFrame containing more than 10% garbage value.
df.drop(['CO(GT)','NMHC(GT)','NOx(GT)','NO2(GT)'],axis=1, inplace=True)

# %%
#Again, calculate the percentage of rows containing '-200' in each column except for the 'DateTime', 'Year', 'Month' and 'Day' columns.
count_list=[[col,df[df[col]==-200].shape[0]] for col in df.columns[1:-4]]
percent_list=[[count_list[i][0],round((count_list[i][1])*100/df.shape[0],3)]for i in range(len(count_list))]
percent_list
# Out:
# [['PT08.S1(CO)', 3.912],
#  ['C6H6(GT)', 3.912],
#  ['PT08.S2(NMHC)', 3.912],
#  ['PT08.S3(NOx)', 3.912],
#  ['PT08.S4(NO2)', 3.912],
#  ['PT08.S5(O3)', 3.912],
#  ['T', 3.912],
#  ['RH', 3.912],
#  ['AH', 3.912]]

# %%
df['Year'].unique()
# Out:
# array([2004, 2005], dtype=int64)

# %%
#Calculate the median values for the columns having indices between 1 and -4 (excluding -4) for the year 2004.
df.loc[df['Year']==2004, df.columns[1:-4]].describe()
# Out:
#        PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# count  7110.000000  7110.000000     7110.00000   7110.000000   7110.000000
# mean   1055.135443     3.876779      923.60661    822.454571   1495.659353
# std     314.719517    37.859514      332.55071    315.705690    433.109562
# min    -200.000000  -200.000000     -200.00000   -200.000000   -200.000000
# 25%     919.000000     4.600000      741.00000    666.000000   1331.250000
# 50%    1052.000000     8.600000      923.00000    815.000000   1528.000000
# 75%    1221.000000    14.200000     1124.00000    982.000000   1726.000000
# max    2040.000000    63.700000     2214.00000   2683.000000   2775.000000
#
#        PT08.S5(O3)            T           RH           AH
# count  7110.000000  7110.000000  7110.000000  7110.000000
# mean    973.985513    13.779001    40.292053    -5.310343
# std     434.094624    39.705743    46.983126    35.441047
# min    -200.000000  -200.000000  -200.000000  -200.000000
# ...

# %%
df.loc[df['Year']==2005, df.columns[1:-4]].describe()
# Out:
#        PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# count  2247.000000  2247.000000    2247.000000   2247.000000   2247.000000
# mean   1029.544726    -4.497864     802.797063    708.086782   1061.832221
# std     373.059005    50.426047     356.435107    326.303957    415.312391
# min    -200.000000  -200.000000    -200.000000   -200.000000   -200.000000
# 25%     925.500000     2.900000     643.500000    553.500000    906.000000
# 50%    1055.000000     5.800000     805.000000    721.000000   1084.000000
# 75%    1222.000000    11.200000    1021.500000    893.500000   1297.000000
# max    1846.000000    43.000000    1831.000000   1881.000000   2147.000000
#
#        PT08.S5(O3)            T           RH           AH
# count  2247.000000  2247.000000  2247.000000  2247.000000
# mean    978.510013    -2.880774    36.932888   -11.670190
# std     522.776411    50.737736    62.700754    48.186199
# min    -200.000000  -200.000000  -200.000000  -200.000000
# ...

# %%
#Garbage Value Replacement^^^
#Count the number of rows containing '2004' and '2005' year values.
df['Year'].value_counts()
# Out:
# 2004    7110
# 2005    2247
# Name: Year, dtype: int64

# %%
# Create a new DataFrame containing records for the year 2004. Also, display the first five rows.
aq2004_df= df[df['Year']==2004]
aq2004_df.head()
# Out:
#              Datetime  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0 2004-03-10 18:00:00       1360.0      11.9         1046.0        1056.0
# 1 2004-03-10 19:00:00       1292.0       9.4          955.0        1174.0
# 2 2004-03-10 20:00:00       1402.0       9.0          939.0        1140.0
# 3 2004-03-10 21:00:00       1376.0       9.2          948.0        1092.0
# 4 2004-03-10 22:00:00       1272.0       6.5          836.0        1205.0
#
#    PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  Year  Month        Date  \
# 0        1692.0       1268.0  13.6  48.9  0.7578  2004      3  2004-03-10
# 1        1559.0        972.0  13.3  47.7  0.7255  2004      3  2004-03-10
# 2        1555.0       1074.0  11.9  54.0  0.7502  2004      3  2004-03-10
# 3        1584.0       1203.0  11.0  60.0  0.7867  2004      3  2004-03-10
# 4        1490.0       1110.0  11.2  59.6  0.7888  2004      3  2004-03-10
#
#      Dayname
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# ...

# %%
aq2004_df.shape
# Out:
# (7110, 14)

# %%
## Create a new DataFrame containing records for the year 2005. Also, display the first five rows.
aq2005_df= df[df['Year']==2005]
aq2005_df
# Out:
#                 Datetime  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 7110 2005-01-01 00:00:00       1046.0       4.2          724.0         848.0
# 7111 2005-01-01 01:00:00       1275.0       8.8          930.0         649.0
# 7112 2005-01-01 02:00:00       1173.0       7.5          878.0         738.0
# 7113 2005-01-01 03:00:00       1163.0       7.6          881.0         748.0
# 7114 2005-01-01 04:00:00       1054.0       5.6          791.0         830.0
# ...                  ...          ...       ...            ...           ...
# 9352 2005-04-04 10:00:00       1314.0      13.5         1101.0         539.0
# 9353 2005-04-04 11:00:00       1163.0      11.4         1027.0         604.0
# 9354 2005-04-04 12:00:00       1142.0      12.4         1063.0         603.0
# 9355 2005-04-04 13:00:00       1003.0       9.5          961.0         702.0
# 9356 2005-04-04 14:00:00       1071.0      11.9         1047.0         654.0
#
# ...

# %%
air_quality_2005.shape
# Out:
# (2247, 14)

# %%
#Replace the -200 value with the median values for each column having indices between 1 and -4 (excluding -4) for the 2004 year DataFrame.
for cols in aq2004_df.columns[1:-4]:
    median=aq2004_df[cols].median()
    aq2004_df[cols].replace(-200,median)

# %%
for cols in aq2005_df.columns[1:-4]:
    median=aq2005_df[cols].median()
    aq2005_df[cols].replace(-200,median)

# %%
#Compute the number of rows containing '-200' in each column having indices between 1 and -4 (excluding -4) in the 2004 year DataFrame.
count_list_2004=[[cols, aq2004_df[aq2004_df[cols]==-200].shape[0]] for cols in aq2004_df.columns[1:-4]]
percent_list_2004= [[count_list_2004[i][0], round((count_list_2004[i][1])*100/ df.shape[0],2)] for i in range(len(count_list_2004))]
percent_list_2004
# Out:
# [['PT08.S1(CO)', 2.44],
#  ['C6H6(GT)', 2.44],
#  ['PT08.S2(NMHC)', 2.44],
#  ['PT08.S3(NOx)', 2.44],
#  ['PT08.S4(NO2)', 2.44],
#  ['PT08.S5(O3)', 2.44],
#  ['T', 2.44],
#  ['RH', 2.44],
#  ['AH', 2.44]]

# %%
count_list_2005=[[cols, aq2005_df[aq2005_df[cols]==-200].shape[0]] for cols in aq2005_df.columns[1:-4]]
percent_list_2005= [[count_list_2005[i][0], round((count_list_2005[i][1])*100/ df.shape[0],2)] for i in range(len(count_list_2005))]
percent_list_2005
# Out:
# [['PT08.S1(CO)', 1.47],
#  ['C6H6(GT)', 1.47],
#  ['PT08.S2(NMHC)', 1.47],
#  ['PT08.S3(NOx)', 1.47],
#  ['PT08.S4(NO2)', 1.47],
#  ['PT08.S5(O3)', 1.47],
#  ['T', 1.47],
#  ['RH', 1.47],
#  ['AH', 1.47]]

# %%
#Group the records for the 2004 DataFrame together by month.
aq2004_groupby_month=aq2004_df.groupby(by='Month')
aq2004_groupby_month.head(100)
# Out:
#                 Datetime  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0    2004-03-10 18:00:00       1360.0      11.9         1046.0        1056.0
# 1    2004-03-10 19:00:00       1292.0       9.4          955.0        1174.0
# 2    2004-03-10 20:00:00       1402.0       9.0          939.0        1140.0
# 3    2004-03-10 21:00:00       1376.0       9.2          948.0        1092.0
# 4    2004-03-10 22:00:00       1272.0       6.5          836.0        1205.0
# ...                  ...          ...       ...            ...           ...
# 6461 2004-12-04 23:00:00       1054.0       5.6          794.0         830.0
# 6462 2004-12-05 00:00:00       1096.0       6.3          826.0         795.0
# 6463 2004-12-05 01:00:00       1042.0       6.5          834.0         808.0
# 6464 2004-12-05 02:00:00        887.0       3.4          679.0         969.0
# 6465 2004-12-05 03:00:00        884.0       3.0          651.0        1034.0
#
# ...

# %%
## Get all the records for the month of March.
aq2004_groupby_month.get_group(3)
# Out:
#                Datetime  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0   2004-03-10 18:00:00       1360.0      11.9         1046.0        1056.0
# 1   2004-03-10 19:00:00       1292.0       9.4          955.0        1174.0
# 2   2004-03-10 20:00:00       1402.0       9.0          939.0        1140.0
# 3   2004-03-10 21:00:00       1376.0       9.2          948.0        1092.0
# 4   2004-03-10 22:00:00       1272.0       6.5          836.0        1205.0
# ..                  ...          ...       ...            ...           ...
# 505 2004-03-31 19:00:00       1254.0      11.5         1033.0         819.0
# 506 2004-03-31 20:00:00       1198.0       9.3          953.0         882.0
# 507 2004-03-31 21:00:00       1060.0       5.5          787.0        1044.0
# 508 2004-03-31 22:00:00       1050.0       5.1          769.0        1078.0
# 509 2004-03-31 23:00:00       1029.0       4.8          754.0        1098.0
#
# ...

# %%
aq2005_groupby_month=aq2005_df.groupby(by='Month')
aq2005_groupby_month.head()
# Out:
#                 Datetime  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 7110 2005-01-01 00:00:00       1046.0       4.2          724.0         848.0
# 7111 2005-01-01 01:00:00       1275.0       8.8          930.0         649.0
# 7112 2005-01-01 02:00:00       1173.0       7.5          878.0         738.0
# 7113 2005-01-01 03:00:00       1163.0       7.6          881.0         748.0
# 7114 2005-01-01 04:00:00       1054.0       5.6          791.0         830.0
# 7854 2005-02-01 00:00:00       1038.0       4.8          756.0         813.0
# 7855 2005-02-01 01:00:00        996.0       3.8          698.0         871.0
# 7856 2005-02-01 02:00:00        995.0       3.5          680.0         879.0
# 7857 2005-02-01 03:00:00       1000.0       3.3          670.0         868.0
# 7858 2005-02-01 04:00:00       1042.0       3.6          688.0         814.0
# 8526 2005-03-01 00:00:00        766.0       1.2          515.0        1327.0
# ...

# %%
#Get the descriptive statistics for March 2004.
aq2004_groupby_month.get_group(3).describe()
# Out:
#        PT08.S1(CO)    C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# count   510.000000  510.000000     510.000000    510.000000    510.000000
# mean   1222.819608    9.932745     935.643137   1029.172549   1572.072549
# std     241.038541    7.060527     258.997406    268.130898    280.525357
# min     818.000000    0.600000     457.000000    537.000000   1050.000000
# 25%    1027.250000    4.600000     742.250000    834.250000   1359.000000
# 50%    1197.000000    8.650000     926.000000    966.500000   1543.000000
# 75%    1383.000000   13.650000    1106.250000   1175.500000   1730.000000
# max    2040.000000   39.200000    1754.000000   1935.000000   2679.000000
#
#        PT08.S5(O3)           T          RH          AH    Year  Month
# count   510.000000  510.000000  510.000000  510.000000   510.0  510.0
# mean   1027.494118   14.390784   50.170784    0.789413  2004.0    3.0
# std     381.600387    4.447539   14.265312    0.139932     0.0    0.0
# ...

# %%
#Get the descriptive statistics for March 2005.
aq2005_groupby_month.get_group(3).describe()
# Out:
#        PT08.S1(CO)    C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# count   744.000000  744.000000     744.000000     744.00000    744.000000
# mean   1143.508065    8.449194     886.361559     708.18414   1223.428763
# std     203.200635   10.155621     256.425380     218.94442    280.808936
# min    -200.000000 -200.000000    -200.000000    -200.00000   -200.000000
# 25%     995.250000    3.675000     690.750000     551.00000   1054.000000
# 50%    1126.000000    6.600000     841.000000     682.00000   1217.000000
# 75%    1267.500000   12.100000    1052.500000     830.00000   1376.000000
# max    1818.000000   35.500000    1675.000000    1804.00000   2147.000000
#
#        PT08.S5(O3)           T          RH          AH    Year  Month
# count   744.000000  744.000000  744.000000  744.000000   744.0  744.0
# mean   1081.970430   12.932258   50.570699    0.511866  2005.0    3.0
# std     411.641963   10.097967   18.976852    7.366790     0.0    0.0
# ...

# %%
#Get the descriptive statistics for all the months for the year 2004.
aq2004_groupby_month.describe()
# Out:
#       PT08.S1(CO)                                                            \
#             count         mean         std    min      25%     50%      75%
# Month
# 3           510.0  1222.819608  241.038541  818.0  1027.25  1197.0  1383.00
# 4           720.0  1111.743056  344.463497 -200.0   956.00  1115.5  1317.50
# 5           744.0  1052.641129  260.140865 -200.0   923.50  1047.0  1196.00
# 6           720.0   956.362500  315.391194 -200.0   870.00  1009.5  1121.50
# 7           744.0  1044.759409  164.776466 -200.0   930.00  1031.5  1138.50
# 8           744.0   903.275538  315.381302 -200.0   871.75   965.0  1058.00
# 9           720.0  1049.522222  281.163358 -200.0   911.00  1049.5  1217.25
# 10          744.0  1183.052419  248.222366 -200.0   984.00  1159.5  1356.25
# 11          720.0  1132.148611  273.058383  647.0   912.75  1106.5  1311.00
# 12          744.0   948.712366  451.312491 -200.0   876.50   997.5  1199.00
#
# ...

# %%
aq2005_groupby_month.describe()
# Out:
#       PT08.S1(CO)                                                           \
#             count         mean         std    min     25%     50%      75%
# Month
# 1           744.0  1003.467742  418.681901 -200.0  891.00  1046.5  1256.00
# 2           672.0   942.059524  447.703835 -200.0  910.00  1018.0  1155.25
# 3           744.0  1143.508065  203.200635 -200.0  995.25  1126.0  1267.50
# 4            87.0   953.712644  125.441352  811.0  884.50   925.0   969.00
#
#               C6H6(GT)             ...        AH           Year               \
#           max    count       mean  ...       75%     max  count    mean  std
# Month                              ...
# 1      1835.0    744.0  -8.113172  ...  0.812975  1.0567  744.0  2005.0  0.0
# 2      1846.0    672.0 -15.966518  ...  0.614700  1.0859  672.0  2005.0  0.0
# 3      1818.0    744.0   8.449194  ...  0.991450  1.3930  744.0  2005.0  0.0
# 4      1446.0     87.0   4.285057  ...  0.742350  0.8642   87.0  2005.0  0.0
#
#
# ...

# %%
#Get mean, standard deviation and median for all the months for the year 2004.
aq2004_groupby_month.agg(func=('mean', 'std', 'median'))
# Out:
# C:\Users\Lenovo user\AppData\Local\Temp\ipykernel_19724\2477958179.py:2: FutureWarning: ['Datetime', 'Date', 'Dayname'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   aq2004_groupby_month.agg(func=('mean', 'std', 'median'))
#        PT08.S1(CO)                       C6H6(GT)                    \
#               mean         std  median       mean        std median
# Month
# 3      1222.819608  241.038541  1197.0   9.932745   7.060527   8.65
# 4      1111.743056  344.463497  1115.5   2.499583  40.675072   8.10
# 5      1052.641129  260.140865  1047.0   6.263306  29.351027   8.90
# 6       956.362500  315.391194  1009.5  -0.519028  47.552881   9.00
# 7      1044.759409  164.776466  1031.5  10.316398   9.919110   9.90
# 8       903.275538  315.381302   965.0  -6.638978  51.512351   6.00
# 9      1049.522222  281.163358  1049.5   6.265694  33.984608   9.50
# ...

# %%
aq2005_groupby_month.agg(func=('mean', 'std', 'median'))
# Out:
# C:\Users\Lenovo user\AppData\Local\Temp\ipykernel_19724\2422315103.py:1: FutureWarning: ['Datetime', 'Date', 'Dayname'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   aq2005_groupby_month.agg(func=('mean', 'std', 'median'))
#        PT08.S1(CO)                       C6H6(GT)                    \
#               mean         std  median       mean        std median
# Month
# 1      1003.467742  418.681901  1046.5  -8.113172  57.798417    6.0
# 2       942.059524  447.703835  1018.0 -15.966518  65.985373    5.2
# 3      1143.508065  203.200635  1126.0   8.449194  10.155621    6.6
# 4       953.712644  125.441352   925.0   4.285057   3.798394    3.3
#
#       PT08.S2(NMHC)                    PT08.S3(NOx)  ...      T         RH  \
#                mean         std median         mean  ... median       mean
# Month                                                ...
# ...

# %%
#On 'group_2004_month', apply the 'mean', 'std' & 'median' functions on the 'T' column and 'max' function on the 'AH' column.
# Also apply the 'count' function on the 'Month' column.
aq2004_groupby_month.agg(func={'T':('mean', 'std', 'median'), 'AH':'max', 'Month':'count'})
# Out:
#                T                        AH Month
#             mean        std median     max count
# Month
# 3      14.390784   4.447539  14.05  1.0945   510
# 4       8.670694  41.485365  15.90  1.4852   720
# 5      16.136156  30.393510  19.10  1.6296   744
# 6      14.523611  51.003676  24.70  1.9390   720
# 7      29.110753  10.430989  28.05  2.0042   744
# 8      14.039785  57.092472  27.55  2.1806   744
# 9      19.004861  35.506348  23.60  2.2310   720
# 10     20.201210   8.843783  20.30  2.0224   744
# 11     13.485417   4.990447  13.25  1.9800   720
# 12    -11.562500  65.540769  11.05  1.3713   744

# %%
#For winters of 2004, get the quartiles of all the air pollutants, temperature, relative humidity and absolute humidity.
for col in aq2004_df.columns[1:-4]:
    print('\n', aq2004_groupby_month.describe().loc[[3,11,12],[(col,'25%'),(col,'50%'), (col, '75%')]])
# Out:
#        PT08.S1(CO)
#               25%     50%     75%
# Month
# 3         1027.25  1197.0  1383.0
# 11         912.75  1106.5  1311.0
# 12         876.50   997.5  1199.0
#
#        C6H6(GT)
#            25%    50%    75%
# Month
# 3          4.6   8.65  13.65
# 11         5.0  10.10  17.60
# 12         3.0   6.60  12.50
#
#        PT08.S2(NMHC)
#                 25%    50%      75%
# Month
# 3            742.25  926.0  1106.25
# 11           762.50  981.0  1227.25
# 12           650.50  838.5  1067.00
#
#        PT08.S3(NOx)
#                25%    50%     75%
# Month
# 3           834.25  966.5  1175.5
# 11          558.75  722.5   923.0
# 12          587.00  775.0   981.5
#
#        PT08.S4(NO2)
#                25%     50%     75%
# Month
# 3          1359.00  1543.0  1730.0
# 11         1111.00  1313.5  1597.5
# 12          947.75  1142.5  1330.0
#
#        PT08.S5(O3)
#               25%     50%      75%
# Month
# 3          762.50   992.5  1272.00
# ...

# %%
for col in aq2005_df.columns[1:-4]:
    print('\n', aq2005_groupby_month.describe().loc[[1,2,3],[(col,'25%'),(col,'50%'), (col, '75%')]])
# Out:
#        PT08.S1(CO)
#               25%     50%      75%
# Month
# 1          891.00  1046.5  1256.00
# 2          910.00  1018.0  1155.25
# 3          995.25  1126.0  1267.50
#
#        C6H6(GT)
#            25%  50%   75%
# Month
# 1        2.600  6.0  13.1
# 2        2.475  5.2   9.5
# 3        3.675  6.6  12.1
#
#        PT08.S2(NMHC)
#                 25%    50%      75%
# Month
# 1            629.00  813.5  1087.25
# 2            616.50  775.0   960.00
# 3            690.75  841.0  1052.50
#
#        PT08.S3(NOx)
#                25%    50%     75%
# Month
# 1           534.75  733.5  932.00
# 2           573.00  730.0  897.25
# 3           551.00  682.0  830.00
#
#        PT08.S4(NO2)
#                25%     50%      75%
# Month
# 1           876.00  1072.0  1319.75
# 2           849.25   979.0  1160.25
# 3          1054.00  1217.0  1376.00
#
#        PT08.S5(O3)
#               25%     50%      75%
# Month
# 1          630.25   992.0  1420.50
# ...

# %%
aq2005_df['Month'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
# Create a line plot for the monthly median concentration of CO in 2004.
# Group the DataFrames month-wise such that the 'Month' column is not an index.
group_2004_month= aq2004_df.groupby(by='Month', as_index=False)
group_2005_month= aq2005_df.groupby(by='Month', as_index=False)
month_2004_name=aq2004_df['Month'].unique()

plt.figure(figsize=(12,6))
plt.title("Monthly median CO 2004")
plt.plot(group_2004_month.median()['Month'],group_2004_month.median()['PT08.S1(CO)'],'--o')
plt.xlabel('MONTH')
plt.ylabel('SENSOR_RESPONSE')
plt.xticks(ticks=group_2004_month.median()['Month'],labels=month_2004_name,rotation=45)
plt.grid(True)
plt.show()

# %%
group_2004_month.median()
# Out:
#    Month  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# 0      3       1197.0      8.65          926.0         966.5        1543.0
# 1      4       1115.5      8.10          903.0         882.0        1555.0
# 2      5       1047.0      8.90          937.0         910.0        1565.0
# 3      6       1009.5      9.00          939.0         846.5        1683.0
# 4      7       1031.5      9.90          972.5         786.0        1607.5
# 5      8        965.0      6.00          813.0         807.0        1554.0
# 6      9       1049.5      9.50          958.5         788.0        1488.5
# 7     10       1159.5     11.10         1019.0         660.0        1576.5
# 8     11       1106.5     10.10          981.0         722.5        1313.5
# 9     12        997.5      6.60          838.5         775.0        1142.5
#
#    PT08.S5(O3)      T     RH       AH    Year
# 0        992.5  14.05  52.20  0.79205  2004.0
# 1        939.5  15.90  50.10  0.90875  2004.0
# ...

# %%
#visualise the monthly median temperature variation for the year 2004.
list1=['jan', 'feb', 'mar', 'apr', 'may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
plt.figure(figsize=(12,8))
plt.title("MONTHLY MEDIAN OF TEMP IN 2004")
plt.bar(x=np.arange(0,10), height= group_2004_month.median()['T'])
plt.xticks(ticks=np.arange(0,10), labels=list1[2:])
plt.show()

# %%
# month wise bar plots for all the air pollutants, temperature, relative & absolute humidity in the DataFrame for the year 2005.
for i in aq2005_df.columns[1:-4]:
    plt.figure(figsize=(12,8))
    plt.title("MONTHLY MEDIAN OF "+i+" IN 2005")
    plt.bar(x=np.arange(0,4), height= group_2005_month.median()[i], width= 0.5)
    plt.xticks(ticks=np.arange(0,4), labels=list1[0:4])
    plt.show()

# %%
#bar plot for both the DataFrames to compare the monthly median temperature variation in 2004 and 2005.
plt.figure(figsize=(12,6))
plt.title("monthly median temperature variation in 2004 and 2005")
plt.bar(x=np.arange(3,13)-0.4/2, height=group_2004_month.median()['T'], width=0.4, label='2004')
plt.bar(x=np.arange(1,5)+0.4/2, height=group_2005_month.median()['T'], width=0.4, label='2005')
plt.xticks(ticks=np.arange(1,13), labels=list1)
plt.legend()
plt.show()

# %%
#bar plot to visualise monthly mean temperature variation in 2004.
plt.figure(figsize=(16,8))
sns.barplot(x=aq2004_df['Month'], y=aq2004_df['T'], ci=None)
plt.xticks(ticks=np.arange(10), labels=list1[2:])
plt.show()

# %%
from numpy import median
plt.figure(figsize=(14,5))
sns.barplot(y=df['Month'], x=df['T'], estimator= median, ci= None, orient='h')
plt.yticks(ticks=np.arange(12), labels=list1)
plt.show()

# %%
def lineplot(width,height,x,y,color,label):
  plt.figure(figsize=(width,height))
  plt.plot(x,y,color=color,label=label)
  plt.legend()
  plt.show()

# %%
#line plot to visualise the monthly median concentration of carbon monoxide and ozone in the year 2005.
lineplot(8,4, np.arange(1,5), group_2005_month.median()['PT08.S1(CO)'],'blue','CO')
lineplot(8,4, np.arange(1,5), group_2005_month.median()['PT08.S5(O3)'],'orange','O3')
lineplot(8,4,np.arange(1,5),group_2005_month.median()['PT08.S1(CO)'],'red','CO')
lineplot(8,4,np.arange(1,5),group_2005_month.median()['PT08.S3(NOx)'],'black','NOx')

# %%
#regression plot for the carbon monoxide and nitrogen oxide columns.
plt.figure(figsize=(13,5))
sns.regplot(x=df['PT08.S1(CO)'],y=df['PT08.S3(NOx)'],color='brown')
plt.xlabel('CO')
plt.ylabel('NOx')
plt.show()

# %%
plt.figure(figsize=(13,5))
sns.regplot(x=df['PT08.S1(CO)'],y=df['PT08.S5(O3)'],color='purple')
plt.xlabel('CO')
plt.ylabel('O3')
plt.show()

# %%
print(np.corrcoef(df['PT08.S1(CO)'],df['PT08.S5(O3)']))
print(np.corrcoef(df['PT08.S1(CO)'],df['PT08.S3(NOx)']))
# Out:
# [[1.         0.89243443]
#  [0.89243443 1.        ]]
# [[1.         0.08701943]
#  [0.08701943 1.        ]]

# %%
corr_df=df.iloc[:,1:-4].corr()
corr_df
# Out:
#                PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# PT08.S1(CO)       1.000000  0.852687       0.933102      0.087019
# C6H6(GT)          0.852687  1.000000       0.767433      0.512193
# PT08.S2(NMHC)     0.933102  0.767433       1.000000     -0.073667
# PT08.S3(NOx)      0.087019  0.512193      -0.073667      1.000000
# PT08.S4(NO2)      0.845149  0.774673       0.874782      0.122734
# PT08.S5(O3)       0.892434  0.641334       0.909905     -0.208865
# T                 0.754844  0.971375       0.669025      0.588111
# RH                0.745375  0.925062       0.585803      0.573549
# AH                0.764903  0.984555       0.646572      0.621618
#
#                PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# PT08.S1(CO)        0.845149     0.892434  0.754844  0.745375  0.764903
# C6H6(GT)           0.774673     0.641334  0.971375  0.925062  0.984555
# PT08.S2(NMHC)      0.874782     0.909905  0.669025  0.585803  0.646572
# ...

# %%
#In the above heatmap, the cells having lighter colour densities denote greatest positive correlation between two columns and 
#the cells having darker colour densities denote greatest negative correlation between two columns.

#You can change the colour scheme of a heatmap by specifying another colour scheme using the `cmap` parameter, eg: cmap='YlGnBu'

# Create a heatmap to pinpoint the columns in the 'df' DataFrame exhibiting high correlation.
plt.figure(figsize=(15,4))
sns.heatmap(data=corr_df, annot=True)
plt.show
#cells with darker color densities denotes
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
